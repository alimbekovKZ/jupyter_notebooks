# %%
#https://github.com/sainathadapa/kaggle-freesound-audio-tagging

# %%
# !ls
# Out:
# sample_data

# %%
# !git clone https://github.com/sainathadapa/kaggle-freesound-audio-tagging.git
# Out:
# Cloning into 'kaggle-freesound-audio-tagging'...
# remote: Enumerating objects: 29, done.
# remote: Total 29 (delta 0), reused 0 (delta 0), pack-reused 29
# Unpacking objects: 100% (29/29), done.

# %%
# !ls
# Out:
# kaggle-freesound-audio-tagging	sample_data

# %%
cd kaggle-freesound-audio-tagging/
# Out:
# /content/kaggle-freesound-audio-tagging

# %%
ls
# Out:
# 01-save-trimmed-wavs.py        LICENSE
# 02-compute-mel-specs.py        mel_and_pca_model_funcs.py
# 03-compute-summary-feats.py    mel_model_funcs.py
# 04-pca.py                      README.md
# 05-ten-folds.py                requirements.txt
# 06-train-model-only-mel.py     run_all.sh*
# 07-train-model-mel-and-pca.py  setup.cfg
# 08-generate-predictions.py     summary_feats_funcs.py
# approaches_all.md              utils.py

# %%
mkdir data

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-155ee50c-0b7a-4dee-b4ef-baa30a03fc56" name="files[]" multiple disabled />
#      <output id="result-155ee50c-0b7a-4dee-b4ef-baa30a03fc56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 67 bytes

# %%
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions list
# Out:
# ref                                                deadline             category            reward  teamCount  userHasEntered
# -------------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# digit-recognizer                                   2030-01-01 00:00:00  Getting Started  Knowledge       3018            True
# titanic                                            2030-01-01 00:00:00  Getting Started  Knowledge      11350            True
# house-prices-advanced-regression-techniques        2030-01-01 00:00:00  Getting Started  Knowledge       4584           False
# imagenet-object-localization-challenge             2029-12-31 07:00:00  Research         Knowledge         37           False
# competitive-data-science-predict-future-sales      2019-12-31 23:59:00  Playground           Kudos       3118            True
# ...

# %%
# !kaggle competitions download -c freesound-audio-tagging-2019
# Out:
# ...
# 100% 20.0G/20.0G [04:06<00:00, 80.1MB/s]
# 100% 20.0G/20.0G [04:06<00:00, 87.3MB/s]
# ...
#   0% 0.00/571k [00:00<?, ?B/s]
# 100% 571k/571k [00:00<00:00, 181MB/s]
# ...
#  99% 2.23G/2.24G [00:22<00:00, 130MB/s]
# 100% 2.24G/2.24G [00:22<00:00, 105MB/s]
# ...
#   0% 0.00/140k [00:00<?, ?B/s]
# 100% 140k/140k [00:00<00:00, 139MB/s]
# ...
#   0% 0.00/190k [00:00<?, ?B/s]
# 100% 190k/190k [00:00<00:00, 148MB/s]
# ...
#  98% 654M/666M [00:08<00:00, 111MB/s]
# 100% 666M/666M [00:08<00:00, 82.0MB/s]

# %%
ls
# Out:
# 01-save-trimmed-wavs.py        README.md
# 02-compute-mel-specs.py        requirements.txt
# 03-compute-summary-feats.py    run_all.sh*
# 04-pca.py                      sample_submission.csv
# 05-ten-folds.py                setup.cfg
# 06-train-model-only-mel.py     summary_feats_funcs.py
# 07-train-model-mel-and-pca.py  test.zip
# 08-generate-predictions.py     train_curated.csv
# approaches_all.md              train_curated.zip
# data/                          train_noisy.csv
# LICENSE                        train_noisy.zip
# mel_and_pca_model_funcs.py     utils.py
# mel_model_funcs.py

# %%
# !pip3 install virtualenv
# Out:
# ...
#      |████████████████████████████████| 2.0MB 3.5MB/s
# ...

# %%
# !unzip train_curated.zip -d data
# Out:
# Archive:  train_curated.zip
#   inflating: data/c1b84d6f.wav
#   inflating: data/37acc887.wav
#   inflating: data/8d1fb22b.wav
#   inflating: data/fd621ec3.wav
#   inflating: data/b2196421.wav
#   inflating: data/5ea6937f.wav
#   inflating: data/03ea2668.wav
#   inflating: data/d3184ca4.wav
#   inflating: data/775a890a.wav
#   inflating: data/a25aedbc.wav
#   inflating: data/50242b6c.wav
#   inflating: data/59099afd.wav
#   inflating: data/08f26926.wav
#   inflating: data/3ede79fd.wav
#   inflating: data/23ee33f6.wav
#   inflating: data/7419fde6.wav
#   inflating: data/84e4fa67.wav
#   inflating: data/cbc963cb.wav
#   inflating: data/950b1afa.wav
#   inflating: data/9950cecb.wav
#   inflating: data/92601183.wav
#   inflating: data/8ebf9f33.wav
#   inflating: data/824d9810.wav
#   inflating: data/77e2a2d8.wav
#   inflating: data/1d35e64d.wav
#   inflating: data/5f9e42a3.wav
#   inflating: data/8af07df0.wav
#   inflating: data/4c34b491.wav
#   inflating: data/9b405966.wav
# ...

# %%
# !unzip train_noisy.zip -d data
# Out:
# Archive:  train_noisy.zip
#   inflating: data/6dd81c5a.wav
#   inflating: data/8673f1a1.wav
#   inflating: data/0eb824eb.wav
#   inflating: data/f97e8551.wav
#   inflating: data/84ca96ab.wav
#   inflating: data/5f909074.wav
#   inflating: data/5e71e8b1.wav
#   inflating: data/76ccf020.wav
#   inflating: data/1f674089.wav
#   inflating: data/9740dda6.wav
#   inflating: data/5094db8a.wav
#   inflating: data/27b09d82.wav
#   inflating: data/5cebe76a.wav
#   inflating: data/c625c68a.wav
#   inflating: data/91a3fb1c.wav
#   inflating: data/8c712129.wav
#   inflating: data/537e5a92.wav
#   inflating: data/f8006010.wav
#   inflating: data/9a1f4d48.wav
#   inflating: data/b510e20b.wav
#   inflating: data/110f7af6.wav
#   inflating: data/edcf2409.wav
#   inflating: data/30129f45.wav
#   inflating: data/2c625ed4.wav
#   inflating: data/7ff62b96.wav
#   inflating: data/0946ff5a.wav
#   inflating: data/4be2013c.wav
#   inflating: data/931150d4.wav
#   inflating: data/a18d0105.wav
# ...

# %%
# !/bin/bash run_all.sh
# Out:
# Already using interpreter /usr/bin/python3
# Using base prefix '/usr'
# New python executable in /content/kaggle-freesound-audio-tagging/.env/bin/python3
# Also creating executable in /content/kaggle-freesound-audio-tagging/.env/bin/python
# Installing setuptools, pip, wheel...
# done.
# ...
#      |████████████████████████████████| 92kB 4.3MB/s
# ...
#      |████████████████████████████████| 153kB 10.9MB/s
# ...
#      |████████████████████████████████| 143kB 51.0MB/s
# ...
#      |████████████████████████████████| 9.3MB 39.6MB/s
# ...
#      |████████████████████████████████| 2.8MB 32.8MB/s
# ...
#      |████████████████████████████████| 61kB 25.1MB/s
# ...
#      |████████████████████████████████| 757kB 45.4MB/s
# ...
#      |████████████████████████████████| 184kB 49.9MB/s
# ...
#      |████████████████████████████████| 276kB 41.1MB/s
# ...
#      |████████████████████████████████| 307kB 48.9MB/s
# ...
#      |████████████████████████████████| 51kB 23.3MB/s
# ...
#      |████████████████████████████████| 1.6MB 23.0MB/s
# ...
