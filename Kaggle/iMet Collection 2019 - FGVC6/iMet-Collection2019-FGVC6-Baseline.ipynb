# %% [markdown]
# https://github.com/xungeer29/iMet-Collection2019-FGVC6-Baseline

# %%
# !ls
# Out:
# sample_data

# %%
# !pip install kaggle

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-bdd8040f-004b-423b-836c-f792098dc80f" name="files[]" multiple disabled />
#      <output id="result-bdd8040f-004b-423b-836c-f792098dc80f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 67 bytes

# %%
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions list
# Out:
# ref                                                deadline             category            reward  teamCount  userHasEntered
# -------------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# digit-recognizer                                   2030-01-01 00:00:00  Getting Started  Knowledge       3025            True
# titanic                                            2030-01-01 00:00:00  Getting Started  Knowledge      11376            True
# house-prices-advanced-regression-techniques        2030-01-01 00:00:00  Getting Started  Knowledge       4765           False
# imagenet-object-localization-challenge             2029-12-31 07:00:00  Research         Knowledge         38           False
# competitive-data-science-predict-future-sales      2019-12-31 23:59:00  Playground           Kudos       3229            True
# ...

# %%
# !kaggle competitions download -c imet-2019-fgvc6
# Out:
# ...
#   0% 0.00/167k [00:00<?, ?B/s]
# 100% 167k/167k [00:00<00:00, 46.8MB/s]
# ...
#  99% 1.40G/1.40G [00:12<00:00, 79.2MB/s]
# 100% 1.40G/1.40G [00:12<00:00, 121MB/s]
# ...
#   0% 0.00/21.7k [00:00<?, ?B/s]
# 100% 21.7k/21.7k [00:00<00:00, 22.1MB/s]
# ...
#   0% 0.00/1.46M [00:00<?, ?B/s]
# 100% 1.46M/1.46M [00:00<00:00, 99.7MB/s]
# ...
# 100% 21.1G/21.1G [03:17<00:00, 89.7MB/s]
# 100% 21.1G/21.1G [03:17<00:00, 115MB/s]

# %%
mkdir train

# %%
mkdir test

# %%
# !unzip train.zip -d train
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#rm -rf test

# %%
#mkdir test

# %%
# !unzip test.zip -d test
# Out:
# Archive:  test.zip
#   inflating: test/10023b2cc4ed5f68.png
#   inflating: test/100fbe75ed8fd887.png
#   inflating: test/101b627524a04f19.png
#   inflating: test/10234480c41284c6.png
#   inflating: test/1023b0e2636dcea8.png
#   inflating: test/1039cd6cf85845c.png
#   inflating: test/103a5b3f83fbe88.png
#   inflating: test/10413aaae8d6a9a2.png
#   inflating: test/10423822b93a65ab.png
#   inflating: test/1052bf702cb099f7.png
#   inflating: test/10543c918a43a8d.png
#   inflating: test/105c9a3453da79c3.png
#   inflating: test/1060688bbf6eac87.png
#   inflating: test/106a247caeabd15a.png
#   inflating: test/106e21606add59f3.png
#   inflating: test/107c38495881b6c9.png
#   inflating: test/108815dd3752ab64.png
#   inflating: test/10943defdd5d5e89.png
#   inflating: test/10a39a78c44ef27c.png
#   inflating: test/10ab70df067bdb4.png
#   inflating: test/10b28e3de3566582.png
#   inflating: test/10b32964331a6cc3.png
#   inflating: test/10b4562e7fa6f668.png
# ...

# %%
# !git clone https://github.com/xungeer29/iMet-Collection2019-FGVC6-Baseline
# Out:
# Cloning into 'iMet-Collection2019-FGVC6-Baseline'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 67 (delta 14), reused 64 (delta 11), pack-reused 0
# Unpacking objects: 100% (67/67), done.

# %%
ls
# Out:
# iMet-Collection2019-FGVC6-Baseline/  sample_submission.csv  train/
# labels.csv                           test/                  train.csv.zip
# sample_data/                         test.zip               train.zip

# %%
cd iMet-Collection2019-FGVC6-Baseline
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline

# %%
ls
# Out:
# config.py  dataset/  inference.py  metrics/   README.md
# data/      figs/     __init__.py   networks/  train.py

# %%
cd dataset/
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline/dataset

# %%
ls
# Out:
# augmentation.py     dataset.py   __init__.py   transforms.py
# augmentation.pyc    dataset.pyc  __init__.pyc  transforms.pyc
# create_img_list.py  EDA.py       __pycache__/

# %%
cd ..
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline

# %%
cd ..
# Out:
# /content

# %%
# !unzip train.csv.zip
# Out:
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
cd iMet-Collection2019-FGVC6-Baseline/
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline

# %%
cd dataset/
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline/dataset

# %%
# !python EDA.py
# Out:
# [4324, 37356, 29200, 20208, 10946, 6157, 920, 103, 17, 5, 1]
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')

# %%
ls
# Out:
# augmentation.py     dataset.py   figs/         __pycache__/
# augmentation.pyc    dataset.pyc  __init__.py   transforms.py
# create_img_list.py  EDA.py       __init__.pyc  transforms.pyc

# %%
# !python create_img_list.py

# %%
cd ..
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline

# %%
ls
# Out:
# config.py  dataset/  inference.py  metrics/   __pycache__/  train.py
# data/      figs/     __init__.py   networks/  README.md

# %%
mkdir utils

# %%
ls
# Out:
# config.py  dataset/  inference.py  metrics/   __pycache__/  train.py
# data/      figs/     __init__.py   networks/  README.md     utils/

# %%
mkdir checkpoints

# %%
cd ..
# Out:
# /content

# %%
cd iMet-Collection2019-FGVC6-Baseline/
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline

# %%
ls
# Out:
# checkpoints/  dataset/      __init__.py  __pycache__/  utils/
# config.py     figs/         metrics/     README.md
# data/         inference.py  networks/    train.py

# %%
cd dataset/
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline/dataset

# %%
ls
# Out:
# augmentation.py     data/        EDA.py       __init__.pyc   transforms.pyc
# augmentation.pyc    dataset.py   figs/        __pycache__/
# create_img_list.py  dataset.pyc  __init__.py  transforms.py

# %%
cd ..
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline

# %%
# !python train.py
# Out:
# ResNet101(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
# ...

# %%
cd ..
# Out:
# /content

# %%
cd iMet-Collection2019-FGVC6-Baseline/
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline

# %%
cd checkpoints/
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline/checkpoints

# %%
ls
# Out:
# ResNet101_python3.pth

# %%
cd ..
# Out:
# /content/iMet-Collection2019-FGVC6-Baseline

# %%
# !python inference.py
# Out:
# 100% 117/117 [02:14<00:00,  1.12it/s]
